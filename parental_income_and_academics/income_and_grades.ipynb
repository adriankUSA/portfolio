# %% [markdown]
# # Adrian Khlim

# %% [markdown]
# ## How Family Income Affects Academics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('graduation_rate.csv')

# %%
df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 1                     29             2090          associate's degree
# 2                     30             2188           bachelor's degree
# 3                     33             2151          associate's degree
# 4                     29             2050          associate's degree
# ..                   ...              ...                         ...
# 995                   32             2234                some college
# 996                   27             1930                some college
# 997                   32             2117          associate's degree
# 998                   32             2034            some high school
# 999                   34             2268           bachelor's degree
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
df.dtypes
# Out:
# ACT composite score              int64
# SAT total score                  int64
# parental level of education     object
# parental income                  int64
# high school gpa                float64
# college gpa                    float64
# years to graduate                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ACT composite score            0
# SAT total score                0
# parental level of education    0
# parental income                0
# high school gpa                0
# college gpa                    0
# years to graduate              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ACT composite score', 'SAT total score', 'parental level of education',
#        'parental income', 'high school gpa', 'college gpa',
#        'years to graduate'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['high school gpa'], df['parental income'], color='skyblue')
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, y='parental income', x='high school gpa', marker='o', color='green')
plt.title('Parental Income vs High School GPA')
plt.xlabel('High School GPA')
plt.ylabel('Parental Income')
# Out:
# Text(0, 0.5, 'Parental Income')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='college gpa', y='parental income', marker='o', color='orange')
plt.title('Parental Income vs College GPA')
plt.xlabel('College GPA')
plt.ylabel('Parental Income')
# Out:
# Text(0, 0.5, 'Parental Income')

# %%
less_than_50000df = df[df['parental income'] < 50000]

# %%
less_than_50000df
# Out:
#      ACT composite score  SAT total score parental level of education  \
# 0                     22             1625                 high school
# 6                     29             2097                some college
# 15                    31             2029                 high school
# 18                    27             1996                 high school
# 56                    22             1717                 high school
# ..                   ...              ...                         ...
# 979                   29             2006                 high school
# 980                   30             2042                some college
# 985                   28             1924            some high school
# 995                   32             2234                some college
# 998                   32             2034            some high school
#
#      parental income  high school gpa  college gpa  years to graduate
# ...

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=less_than_50000df, y='parental income', x='high school gpa', marker='o', color='green')
plt.title('Parental Income vs High School GPA')
plt.xlabel('High School GPA')
plt.ylabel('Parental Income')
# Out:
# Text(0, 0.5, 'Parental Income')

# %%
plt.figure(figsize=(12, 6))
sns.catplot(data=df, x='ACT composite score', y='parental income', kind='box', height=6, aspect=1.5)
plt.title('Parental Income vs ACT Composite Score')
plt.xlabel('ACT Composite Score')
plt.ylabel('Parental Income')
plt.show()

# %%
df['SAT total score'] = df['SAT total score'] / 1.5

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='SAT total score', y='parental income', alpha=0.4)
plt.title("Parental Income vs SAT Total Score")
plt.xlabel("SAT Total Score")
plt.ylabel("Parental Income")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(
    data=df,
    x='SAT total score',
    y='parental income',
    scatter_kws={'alpha':0.3},   # make points semi-transparent
    line_kws={'color':'red'}     # make regression line stand out
)
plt.title("Parental Income vs SAT Total Score with Regression Line")
plt.xlabel("SAT Total Score")
plt.ylabel("Parental Income")
plt.show()

# %%
m, b = np.polyfit(df['parental income'], df['SAT total score'], 1)
print(f"Slope: {m}, Intercept: {b}")
# Out:
# Slope: 0.001404947203171292, Intercept: 1238.6083419435772

# %%
print(f"Slope per $10000: {round(m * 10000, 2)}")
# Out:
# Slope per $10000: 14.05

# %% [markdown]
# ### References
# Kaggle dataset: https://www.kaggle.com/code/adastroabyssosque/parent-s-education-and-child-s-school-performance

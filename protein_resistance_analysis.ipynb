# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Protein Intake and Resistance Training: Optimizing Muscle Hypertrophy

# %% [markdown]
# ## The Problem
# If you’ve ever tried to build muscle, you’ve probably asked yourself: how much protein should I eat? Advice usually ranges from 0.8 to 1 gram of protein per pound of body weight, but that quickly adds up. For someone weighing 250 pounds, that could mean over 250 grams of protein every single day—something that’s not realistic or affordable for most people. So the real question is: does eating that much protein actually help, or is there a point where extra protein doesn’t give extra results? What range of protein intake do diminishing returns begin? How much does bodyweight or lean body mass and protein intake affect muscle hypertrophy?
#
# In this analysis, I will explore data on protein intake and resistance training to discover the optimal range of protein intake for muscle hypertrophy.

# %% [markdown]
# # The Data
# The data I am using for this analysis comes from [Kaggle](https://www.kaggle.com/datasets/fgloblek/protein-intake-and-muscle-mass-data-pmc7727026), titled Protein intake and muscle mass data PMC7727026 by Fran Globlek. There are some important things to note about this dataset. The dataset comes from studies only involving resistance training from "the systematic review and meta-analysis <u>Tagawa R, Watanabe D, Ito K, Ueda K, Nakayama K, Sanbongi C, Miyachi M. Dose-response relationship between protein intake and muscle mass increase: a systematic review and meta-analysis of randomized controlled trials. Nutr Rev. 2020</u> that looked at the dose–response relationship of the effects of protein intake on lean body mass" (Globlek, Frank).
#
# Firstly, what is a **meta-analysis**? A **meta-analysis** is essentially an analysis on a collection of studies, so in this case it was an analysis on a collection of studies on the relationship of protein intake and muscle mass increase with and without resistance training. However, I want to know about optimizing muscle **hypertrophy**, meaning muscle growth, and that includes resistance training. Thus this dataset only contains data from the studies involving resistance training.
#
# The dataset contains 112 rows that are each individual studies, and the 68 columns indicate properties such as the study name, group type (control or experimental), race percentage, ages, LBM (lean body mass which is essentially muscle tissue) info, BMI (body mass index), and of course protein intake and more.

# %%
df = pd.read_csv("PMC7727026_full_data.csv")
len(df.columns)
# Out:
# 68

# %%
df.head()
# Out:
#    Unnamed: 0              Author and Year  Percent male (%)  \
# 0           0          Campbell (1995) [1]                83
# 1           1           Rozenek (2002) [2]               100
# 2           2           Flakoll (2004) [3]               100
# 3           3            Rankin (2004) [4]               100
# 4           4  Layman (2005) (with RT) [5]                 0
#
#   Race with largest number  Age (years)  Height (cm)  Weight (kg)  \
# 0                Caucasian         65.0        173.3         78.0
# 1                Caucasian         23.2        178.3         76.4
# 2                Caucasian         18.9        177.0         74.9
# 3                Caucasian         20.8        177.5         78.9
# 4                Caucasian         46.7        163.2         87.7
#
#    BMI (kg/m2) Health state Frequency of exercise before intervention Other  \
# 0         26.0      Healthy                                         Unclear
# 1         24.1      Healthy                                            High
# 2         23.4      Healthy                                            High
# 3         25.1      Healthy                                         Unclear
# 4         33.0      Healthy                                         Unclear
#
#    ...  Experimental energy intake (kcal/kg/day)  \
# 0  ...                                      37.0
# 1  ...                                      63.3
# 2  ...                                       NaN
# 3  ...                                      33.3
# 4  ...                                       NaN
#
#    Control energy intake (kcal/kg/day)  Study Weight Percentage         Group  \
# 0                                33.80                      0.3  Experimental
# 1                                58.10                      0.5  Experimental
# 2                                  NaN                      0.9  Experimental
# 3                                32.94                      0.6  Experimental
# 4                                  NaN                      1.0  Experimental
#
#    Energy intake (kcal/kg/day)  Protein intake (g/kg/day)  LBM change (kg)  \
# 0                         37.0                       2.40              1.8
# 1                         63.3                       3.30              2.9
# 2                          NaN                        NaN             -2.7
# 3                         33.3                       1.25              1.6
# 4                          NaN                        NaN             -0.4
#
#    LBM change per week (kg/wk)  Relative LBM change  \
# 0                     0.150000             0.023077
# 1                     0.362500             0.037958
# 2                    -0.337500            -0.036048
# 3                     0.160000             0.020279
# 4                    -0.023529            -0.004561
#
#    Relative LBM change per week
# 0                      0.001923
# 1                      0.004745
# 2                     -0.004506
# 3                      0.002028
# 4                     -0.000268
#
# [5 rows x 68 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 68 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Unnamed: 0                                                                   112 non-null    int64
#  1   Author and Year                                                              112 non-null    object
#  2   Percent male (%)                                                             112 non-null    int64
#  3   Race with largest number                                                     112 non-null    object
#  4   Age (years)                                                                  112 non-null    float64
#  5   Height (cm)                                                                  110 non-null    float64
#  6   Weight (kg)                                                                  110 non-null    float64
#  7   BMI (kg/m2)                                                                  112 non-null    float64
#  8   Health state                                                                 112 non-null    object
#  9   Frequency of exercise before intervention Other                              112 non-null    object
#  10  Protein intake before intervention (g/kg/day)                                80 non-null     float64
#  11  Protein intake before intervention (g/day)                                   80 non-null     float64
#  12  Protein intake during intervention (not include supplementation) (g/kg/day)  44 non-null     float64
#  13  Protein intake during intervention (not include supplementation) (g/day)     44 non-null     float64
#  14  Protein intake during intervention (include supplementation) (g/kg/day)      67 non-null     float64
#  15  Protein intake during intervention (include supplementation) (g/day)         69 non-null     float64
#  16  Energy intake before intervention (g/kg/day)                                 80 non-null     float64
#  17  Energy intake before intervention (g/day)                                    80 non-null     float64
#  18  Energy intake during intervention (not include supplementation) (g/kg/day)   40 non-null     float64
#  19  Energy intake during intervention (not include supplementation) (g/day)      40 non-null     float64
#  20  Energy intake during intervention (include supplementation) (g/kg/day)       63 non-null     float64
#  21  Energy intake during intervention (include supplementation) (g/day)          65 non-null     float64
#  22  Assigned protein amount (g/kg/dose)                                          85 non-null     float64
#  23  Assigned protein amount (g/dose)                                             85 non-null     float64
#  24  Assigned protein amount (g/kg/exercise day)                                  89 non-null     float64
#  25  Assigned protein amount (g/exercise day)                                     91 non-null     float64
#  26  Assigned protein amount (g/kg/day)                                           110 non-null    float64
#  27  Assigned protein amount (g/day)                                              112 non-null    float64
#  28  Assigned protein amount (g/kg)                                               110 non-null    float64
#  29  Assigned protein amount (g)                                                  112 non-null    int64
#  30  Difference in protein amount between groups(g/kg/dose)                       85 non-null     float64
#  31  Difference in protein amount between groups(g/dose)                          85 non-null     float64
#  32  Difference in protein amount between groups(g/kg/exercise day)               89 non-null     float64
#  33  Difference in protein amount between groups(g/exercise day)                  91 non-null     float64
#  34  Difference in protein amount between groups(g/kg/day)                        110 non-null    float64
#  35  Difference in protein amount between groups(g/day)                           112 non-null    float64
#  36  Difference in protein amount between groups(g/kg)                            110 non-null    float64
#  37  Difference in protein amount between groups(g)                               112 non-null    int64
#  38  Dietary intervention                                                         112 non-null    object
#  39  Control                                                                      112 non-null    object
#  40  Meal or Supplementation                                                      112 non-null    object
#  41  Protein source                                                               112 non-null    object
#  42  Energy balance                                                               112 non-null    object
#  43  Duration (weeks)                                                             112 non-null    int64
#  44  Type ofExercise                                                              112 non-null    object
#  45  (times/week)                                                                 112 non-null    int64
#  46  Study or Subgroup                                                            112 non-null    object
#  47  Experimental Mean (kg)                                                       112 non-null    float64
#  48  Experimental SD (kg)                                                         112 non-null    float64
#  49  Experimental Total                                                           112 non-null    int64
#  50  Control Mean (kg)                                                            112 non-null    float64
#  51  Control SD (kg)                                                              112 non-null    float64
#  52  Control Total                                                                110 non-null    object
#  53  Mean Difference                                                              112 non-null    float64
#  54  95CI Lower                                                                   112 non-null    float64
#  55  95CI Upper                                                                   110 non-null    object
#  56  Experimental protein intake (g/kg/day)                                       95 non-null     float64
#  57  Control protein intake (g/kg/day)                                            95 non-null     float64
#  58  Experimental energy intake (kcal/kg/day)                                     93 non-null     float64
#  59  Control energy intake (kcal/kg/day)                                          93 non-null     float64
#  60  Study Weight Percentage                                                      112 non-null    float64
#  61  Group                                                                        112 non-null    object
#  62  Energy intake (kcal/kg/day)                                                  93 non-null     float64
#  63  Protein intake (g/kg/day)                                                    95 non-null     float64
#  64  LBM change (kg)                                                              112 non-null    float64
#  65  LBM change per week (kg/wk)                                                  112 non-null    float64
#  66  Relative LBM change                                                          110 non-null    float64
#  67  Relative LBM change per week                                                 110 non-null    float64
# dtypes: float64(47), int64(7), object(14)
# memory usage: 59.6+ KB

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0      Author and Year  Percent male (%)  \
# count   112.000000                  112        112.000000
# unique         NaN                   64               NaN
# top            NaN  Campbell (1995) [1]               NaN
# freq           NaN                    2               NaN
# mean     55.500000                  NaN         68.473214
# std      32.475632                  NaN         39.460314
# min       0.000000                  NaN          0.000000
# 25%      27.750000                  NaN         40.750000
# 50%      55.500000                  NaN        100.000000
# 75%      83.250000                  NaN        100.000000
# max     111.000000                  NaN        100.000000
#
#        Race with largest number  Age (years)  Height (cm)  Weight (kg)  \
# count                       112   112.000000   110.000000   110.000000
# unique                        4          NaN          NaN          NaN
# top                   Caucasian          NaN          NaN          NaN
# freq                         98          NaN          NaN          NaN
# mean                        NaN    41.675000   173.035455    80.387273
# std                         NaN    19.825598     7.525804     8.958919
# min                         NaN    18.900000   155.500000    57.400000
# 25%                         NaN    23.200000   170.000000    76.400000
# 50%                         NaN    34.200000   173.500000    79.100000
# 75%                         NaN    63.500000   178.500000    86.400000
# max                         NaN    78.500000   186.600000    99.200000
#
#         BMI (kg/m2) Health state  \
# count    112.000000          112
# unique          NaN            2
# top             NaN      Healthy
# freq            NaN          105
# mean      26.760714          NaN
# std        2.686850          NaN
# min       22.600000          NaN
# 25%       24.800000          NaN
# 50%       26.200000          NaN
# 75%       28.600000          NaN
# max       34.700000          NaN
#
#        Frequency of exercise before intervention Other  ...  \
# count                                              112  ...
# unique                                               5  ...
# top                                            Unclear  ...
# freq                                                51  ...
# mean                                               NaN  ...
# std                                                NaN  ...
# min                                                NaN  ...
# 25%                                                NaN  ...
# 50%                                                NaN  ...
# 75%                                                NaN  ...
# max                                                NaN  ...
#
#         Experimental energy intake (kcal/kg/day)  \
# count                                  93.000000
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                   31.633548
# std                                     7.569920
# min                                    18.500000
# 25%                                    26.300000
# 50%                                    31.280000
# 75%                                    35.200000
# max                                    63.300000
#
#         Control energy intake (kcal/kg/day)  Study Weight Percentage  \
# count                             93.000000               112.000000
# unique                                  NaN                      NaN
# top                                     NaN                      NaN
# freq                                    NaN                      NaN
# mean                              29.736774                 0.723214
# std                                6.888310                 0.239738
# min                               17.300000                 0.200000
# 25%                               24.800000                 0.600000
# 50%                               29.400000                 0.700000
# 75%                               32.980000                 0.900000
# max                               58.100000                 1.100000
#
#                Group  Energy intake (kcal/kg/day)  Protein intake (g/kg/day)  \
# count            112                    93.000000                  95.000000
# unique             2                          NaN                        NaN
# top     Experimental                          NaN                        NaN
# freq              64                          NaN                        NaN
# mean             NaN                    30.849892                   1.516211
# std              NaN                     7.353709                   0.573406
# min              NaN                    17.300000                   0.220000
# 25%              NaN                    26.160000                   1.130000
# 50%              NaN                    29.560000                   1.400000
# 75%              NaN                    34.200000                   1.780000
# max              NaN                    63.300000                   3.600000
#
#         LBM change (kg)  LBM change per week (kg/wk)  Relative LBM change  \
# count        112.000000                   112.000000           110.000000
# unique              NaN                          NaN                  NaN
# top                 NaN                          NaN                  NaN
# freq                NaN                          NaN                  NaN
# mean           1.150004                     0.096473             0.014615
# std            1.163011                     0.148274             0.014926
# min           -2.930000                    -0.803500            -0.039119
# 25%            0.600000                     0.046074             0.007723
# 50%            1.180000                     0.094167             0.014388
# 75%            1.825000                     0.158750             0.023830
# max            4.300000                     0.416667             0.054777
#
#         Relative LBM change per week
# count                     110.000000
# unique                           NaN
# top                              NaN
# freq                             NaN
# mean                        0.001220
# std                         0.001911
# min                        -0.010158
# 25%                         0.000616
# 50%                         0.001186
# 75%                         0.002051
# max                         0.005944
#
# [11 rows x 68 columns]

# %%
df.shape
# Out:
# (112, 68)

# %%
df_null = df.isnull().sum()
df_null
# Out:
# Percent male (%)                 0
# Age (years)                      0
# Height (cm)                      2
# Weight (kg)                      2
# BMI (kg/m2)                      0
#                                 ..
# Protein intake (g/kg/day)       17
# LBM change (kg)                  0
# LBM change per week (kg/wk)      0
# Relative LBM change              2
# Relative LBM change per week     2
# Length: 63, dtype: int64

# %%
df = df.drop(columns=['Unnamed: 0', 'Author and Year', 'Race with largest number', 'Health state',  'Frequency of exercise before intervention Other'])

# %%
df
# Out:
#      Percent male (%)  Age (years)  Height (cm)  Weight (kg)  BMI (kg/m2)  \
# 0                  83         65.0        173.3         78.0         26.0
# 1                 100         23.2        178.3         76.4         24.1
# 2                 100         18.9        177.0         74.9         23.4
# 3                 100         20.8        177.5         78.9         25.1
# 4                   0         46.7        163.2         87.7         33.0
# ..                ...          ...          ...          ...          ...
# 107                 0         67.6        155.8         62.3         25.7
# 108                 0         64.4        161.5         80.1         30.8
# 109                45         20.8        170.2         73.1         25.2
# 110               100         24.2        186.6         79.9         22.9
# 111                 0         66.7        156.0         65.5         25.1
#
#      Protein intake before intervention (g/kg/day)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                             1.25
# 4                                             0.88
# ..                                             ...
# 107                                           0.83
# 108                                           0.79
# 109                                            NaN
# 110                                           1.45
# 111                                           0.94
#
#      Protein intake before intervention (g/day)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                          98.7
# 4                                          77.0
# ..                                          ...
# 107                                        51.8
# 108                                        61.6
# 109                                         NaN
# 110                                       112.4
# 111                                        61.3
#
#      Protein intake during intervention (not include supplementation) (g/kg/day)  \
# 0                                                  NaN
# 1                                                 1.48
# 2                                                  NaN
# 3                                                 1.25
# 4                                                  NaN
# ..                                                 ...
# 107                                                NaN
# 108                                                NaN
# 109                                               2.20
# 110                                                NaN
# 111                                                NaN
#
#      Protein intake during intervention (not include supplementation) (g/day)  \
# 0                                                  NaN
# 1                                                115.4
# 2                                                  NaN
# 3                                                 98.6
# 4                                                  NaN
# ..                                                 ...
# 107                                                NaN
# 108                                                NaN
# 109                                              154.3
# 110                                                NaN
# 111                                                NaN
#
#      Protein intake during intervention (include supplementation) (g/kg/day)  \
# 0                                                 0.80
# 1                                                 1.70
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 107                                               0.87
# 108                                               0.73
# 109                                                NaN
# 110                                               1.70
# 111                                                NaN
#
#      ...  Experimental energy intake (kcal/kg/day)  \
# 0    ...                                     37.00
# 1    ...                                     63.30
# 2    ...                                       NaN
# 3    ...                                     33.30
# 4    ...                                       NaN
# ..   ...                                       ...
# 107  ...                                     27.66
# 108  ...                                     23.60
# 109  ...                                     35.40
# 110  ...                                     45.04
# 111  ...                                       NaN
#
#      Control energy intake (kcal/kg/day)  Study Weight Percentage  \
# 0                                  33.80                      0.3
# 1                                  58.10                      0.5
# 2                                    NaN                      0.9
# 3                                  32.94                      0.6
# 4                                    NaN                      1.0
# ..                                   ...                      ...
# 107                                26.70                      1.1
# 108                                21.76                      1.0
# 109                                32.76                      0.3
# 110                                43.20                      0.7
# 111                                  NaN                      1.1
#
#             Group  Energy intake (kcal/kg/day)  Protein intake (g/kg/day)  \
# 0    Experimental                        37.00                       2.40
# 1    Experimental                        63.30                       3.30
# 2    Experimental                          NaN                        NaN
# 3    Experimental                        33.30                       1.25
# 4    Experimental                          NaN                        NaN
# ..            ...                          ...                        ...
# 107       Control                        26.70                       0.87
# 108       Control                        21.76                       1.47
# 109       Control                        32.76                       1.54
# 110       Control                        43.20                       1.70
# 111       Control                          NaN                        NaN
#
#      LBM change (kg)  LBM change per week (kg/wk)  Relative LBM change  \
# 0               1.80                     0.150000             0.023077
# 1               2.90                     0.362500             0.037958
# 2              -2.70                    -0.337500            -0.036048
# 3               1.60                     0.160000             0.020279
# 4              -0.40                    -0.023529            -0.004561
# ..               ...                          ...                  ...
# 107             0.70                     0.058333             0.011236
# 108             0.24                     0.024000             0.002996
# 109             1.00                     0.125000             0.013680
# 110             2.25                     0.281250             0.028160
# 111             0.60                     0.050000             0.009160
#
#      Relative LBM change per week
# 0                        0.001923
# 1                        0.004745
# 2                       -0.004506
# 3                        0.002028
# 4                       -0.000268
# ..                            ...
# 107                      0.000936
# 108                      0.000300
# 109                      0.001710
# 110                      0.003520
# 111                      0.000763
#
# [112 rows x 63 columns]

# %%
df_clean = df.dropna(subset=["Protein intake (g/kg/day)", "Relative LBM change", "Relative LBM change per week"])
df_clean
# Out:
#      Percent male (%)  Age (years)  Height (cm)  Weight (kg)  BMI (kg/m2)  \
# 0                  83         65.0        173.3         78.0         26.0
# 1                 100         23.2        178.3         76.4         24.1
# 3                 100         20.8        177.5         78.9         25.1
# 5                 100         64.8        174.0         86.7         28.6
# 6                 100         64.8        174.0         86.7         28.6
# ..                ...          ...          ...          ...          ...
# 106                41         62.5        169.3         92.5         32.3
# 107                 0         67.6        155.8         62.3         25.7
# 108                 0         64.4        161.5         80.1         30.8
# 109                45         20.8        170.2         73.1         25.2
# 110               100         24.2        186.6         79.9         22.9
#
#      Protein intake before intervention (g/kg/day)  \
# 0                                              NaN
# 1                                              NaN
# 3                                             1.25
# 5                                              NaN
# 6                                              NaN
# ..                                             ...
# 106                                           0.95
# 107                                           0.83
# 108                                           0.79
# 109                                            NaN
# 110                                           1.45
#
#      Protein intake before intervention (g/day)  \
# 0                                           NaN
# 1                                           NaN
# 3                                          98.7
# 5                                           NaN
# 6                                           NaN
# ..                                          ...
# 106                                        86.0
# 107                                        51.8
# 108                                        61.6
# 109                                         NaN
# 110                                       112.4
#
#      Protein intake during intervention (not include supplementation) (g/kg/day)  \
# 0                                                  NaN
# 1                                                 1.48
# 3                                                 1.25
# 5                                                 1.26
# 6                                                 1.40
# ..                                                 ...
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                               2.20
# 110                                                NaN
#
#      Protein intake during intervention (not include supplementation) (g/day)  \
# 0                                                  NaN
# 1                                                115.4
# 3                                                 98.6
# 5                                                107.5
# 6                                                122.5
# ..                                                 ...
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                              154.3
# 110                                                NaN
#
#      Protein intake during intervention (include supplementation) (g/kg/day)  \
# 0                                                 0.80
# 1                                                 1.70
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 106                                               0.84
# 107                                               0.87
# 108                                               0.73
# 109                                                NaN
# 110                                               1.70
#
#      ...  Experimental energy intake (kcal/kg/day)  \
# 0    ...                                     37.00
# 1    ...                                     63.30
# 3    ...                                     33.30
# 5    ...                                     28.80
# 6    ...                                     26.60
# ..   ...                                       ...
# 106  ...                                     23.40
# 107  ...                                     27.66
# 108  ...                                     23.60
# 109  ...                                     35.40
# 110  ...                                     45.04
#
#      Control energy intake (kcal/kg/day)  Study Weight Percentage  \
# 0                                  33.80                      0.3
# 1                                  58.10                      0.5
# 3                                  32.94                      0.6
# 5                                  28.28                      0.4
# 6                                  26.08                      0.4
# ..                                   ...                      ...
# 106                                21.40                      0.8
# 107                                26.70                      1.1
# 108                                21.76                      1.0
# 109                                32.76                      0.3
# 110                                43.20                      0.7
#
#             Group  Energy intake (kcal/kg/day)  Protein intake (g/kg/day)  \
# 0    Experimental                        37.00                       2.40
# 1    Experimental                        63.30                       3.30
# 3    Experimental                        33.30                       1.25
# 5    Experimental                        28.80                       1.26
# 6    Experimental                        26.60                       1.40
# ..            ...                          ...                        ...
# 106       Control                        21.40                       1.64
# 107       Control                        26.70                       0.87
# 108       Control                        21.76                       1.47
# 109       Control                        32.76                       1.54
# 110       Control                        43.20                       1.70
#
#      LBM change (kg)  LBM change per week (kg/wk)  Relative LBM change  \
# 0               1.80                     0.150000             0.023077
# 1               2.90                     0.362500             0.037958
# 3               1.60                     0.160000             0.020279
# 5               0.94                     0.078333             0.010842
# 6               0.71                     0.059167             0.008189
# ..               ...                          ...                  ...
# 106             0.20                     0.020000             0.002162
# 107             0.70                     0.058333             0.011236
# 108             0.24                     0.024000             0.002996
# 109             1.00                     0.125000             0.013680
# 110             2.25                     0.281250             0.028160
#
#      Relative LBM change per week
# 0                        0.001923
# 1                        0.004745
# 3                        0.002028
# 5                        0.000903
# 6                        0.000682
# ..                            ...
# 106                      0.000216
# 107                      0.000936
# 108                      0.000300
# 109                      0.001710
# 110                      0.003520
#
# [95 rows x 63 columns]

# %%
df_clean.isnull().sum()
# Out:
# Percent male (%)                0
# Age (years)                     0
# Height (cm)                     0
# Weight (kg)                     0
# BMI (kg/m2)                     0
#                                ..
# Protein intake (g/kg/day)       0
# LBM change (kg)                 0
# LBM change per week (kg/wk)     0
# Relative LBM change             0
# Relative LBM change per week    0
# Length: 63, dtype: int64

# %% [markdown]
# ## Preprocessing
# The first thing I did was identify what kind of data (data types like string/objects, ints, floats) that I have. Then I identified which columns were not relevant and dropped those such as health state and and index numbers and majority race. I also searched for rows with null values and removed those to only use studies with sufficient data.
